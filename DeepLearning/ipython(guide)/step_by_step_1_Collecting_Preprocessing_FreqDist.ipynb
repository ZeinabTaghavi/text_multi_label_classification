# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install bs_ds
# !pip install fake_useragent
# !pip install lxml
# ! pip install scrapy
# ! pip install scrapy_user_agents
# ! ls ./drive/MyDrive/sharif/Spider
# ! pwd

# %%
import os
import pandas as pd
import re
import glob

# %%
os.chdir('./drive/MyDrive/sharif/DeepLearning/ipython(guide)')
os.listdir()
# Out:
# ['step_by_step_3.ipynb',
#  'cnn-for-sentence-classification',
#  'step_by_step_2_Vectorizing_by_model.ipynb',
#  'step_by_step_2_Vectorizing.ipynb',
#  'word2vec_model',
#  'cnn_model.h5',
#  'cnn_for_classification.ipynb',
#  'step_by_step_1_Collecting_Preprocessing_FreqDist.ipynb']

# %%
import os
import pandas as pd
import glob

# %% [markdown]
# ### Making dataset from crawled .csv files

# %%
final_csv_file = pd.DataFrame(columns=['body', 'tag', 'title'])
first_csv_file = pd.DataFrame(columns=['body', 'tag', 'title'])
# final_csv_file = pd.read_csv('dataset.csv')
file_name = glob.glob('../Data/Scraped_data/body_tag_title_*.csv') 
tags_list = pd.read_excel('../Tags.xlsx').values
print(file_name)
# Out:
# ['../Data/Scraped_data/body_tag_title_0.csv', '../Data/Scraped_data/body_tag_title_1.csv', '../Data/Scraped_data/body_tag_title_2.csv', '../Data/Scraped_data/body_tag_title_3.csv', '../Data/Scraped_data/body_tag_title_4.csv', '../Data/Scraped_data/body_tag_title_6.csv']

# %% [markdown]
# ## Merge Taging

# %%
for file_n in file_name:
  matrix_main = pd.read_csv(file_n )
  print(file_n, ' : ', len(matrix_main))
  for i in range(len(matrix_main)):
    matrix_main['tag'][i] = re.sub('Jib:|active|صفحه[\d]+|صفحه [\d]+|,\'active\'|,\'active\',|\'active\',|page=2|<span>|</span>|tag','',matrix_main['tag'][i])
    if matrix_main['tag'][i]=='':
      matrix_main['tag'][i] = None
  matrix_main = matrix_main.dropna(axis=0,inplace=False).reset_index(drop=True)

  counter = 0
  max_counter = 5
  rows_per_iter = 1500
  first_len = len(matrix_main)
  while True:

    counter += 1
    print(' counter: ', counter)
    temp_matrix = pd.DataFrame(columns=['body', 'tag', 'title'])
    pre_len = len(matrix_main)
    for i in range(0, 1+len(matrix_main) // rows_per_iter):
        loop_matrix = matrix_main.loc[i*rows_per_iter:min(first_len,(i+1)*rows_per_iter),:]
        loop_matrix = loop_matrix.dropna(axis=0).reset_index(drop=True)
        for title in loop_matrix['title']:
            indexes = loop_matrix.loc[loop_matrix['title'] == title].index
            if len(indexes) > 0:
                tags = set(loop_matrix.loc[loop_matrix['title'] == title]['tag'])
                tags = re.sub('\{|\}', '', str(tags))
                tags = re.sub('[\']+|[\"]+', '\'', tags)
                loop_matrix.loc[indexes[0], 'title'] = str(title).strip()
                loop_matrix.loc[indexes[0], 'tag'] = tags
                loop_matrix = loop_matrix.drop(axis=0, index=indexes[1:]).reset_index(drop=True)
        temp_matrix = temp_matrix.append(loop_matrix)
        print('  - loop:', len(loop_matrix))
    if len(temp_matrix) > 0:
        matrix_main = temp_matrix.sample(frac=1).reset_index(drop=True)
    print(' - per count: ', len(matrix_main))
    if (counter > max_counter) or (len(matrix_main) == pre_len):
        break
  final_csv_file = final_csv_file.append(matrix_main)
final_csv_file.loc[:,['body','tag']].to_csv('../Data/unpreprocessed_dataset.csv', index=False)
# Out:
# ../spider_1_1  :  12745
#  counter:  1
#   - loop: 980
#   - loop: 246
#  - per count:  1226
#  counter:  2
#   - loop: 1088
#  - per count:  1088
#  counter:  3
#   - loop: 1088
#  - per count:  1088
# ../spider_1_3  :  9112
#  counter:  1
#   - loop: 1054
#   - loop: 1180
#   - loop: 1264
#   - loop: 1108
#   - loop: 1067
#   - loop: 1002
#   - loop: 33
#  - per count:  6708
#  counter:  2
#   - loop: 1178
#   - loop: 1154
#   - loop: 1188
#   - loop: 1166
#   - loop: 623
#  - per count:  5309
#  counter:  3
#   - loop: 1222
#   - loop: 1220
#   - loop: 1225
#   - loop: 720
#  - per count:  4387
#  counter:  4
#   - loop: 1264
#   - loop: 1281
#   - loop: 1180
#  - per count:  3725
#  counter:  5
#   - loop: 1326
#   - loop: 1321
#   - loop: 680
#  - per count:  3327
#  counter:  6
#   - loop: 1355
#   - loop: 1356
#   - loop: 322
#  - per count:  3033
# ../spider_1_0  :  25506
#  counter:  1
#   - loop: 1498
#   - loop: 1500
#   - loop: 1468
#   - loop: 1488
#   - loop: 1491
#   - loop: 1442
#   - loop: 1492
#   - loop: 1475
#   - loop: 1455
#   - loop: 1486
#   - loop: 1496
#   - loop: 1439
#   - loop: 1465
#   - loop: 1486
#   - loop: 1484
#   - loop: 1449
#   - loop: 1338
#  - per count:  24952
#  counter:  2
#   - loop: 1475
#   - loop: 1479
#   - loop: 1484
#   - loop: 1474
#   - loop: 1479
#   - loop: 1486
#   - loop: 1486
#   - loop: 1486
#   - loop: 1481
#   - loop: 1481
#   - loop: 1488
#   - loop: 1485
#   - loop: 1480
#   - loop: 1481
#   - loop: 1472
#   - loop: 1492
#   - loop: 945
#  - per count:  24654
#  counter:  3
#   - loop: 1487
#   - loop: 1491
#   - loop: 1485
#   - loop: 1480
#   - loop: 1486
#   - loop: 1483
#   - loop: 1473
#   - loop: 1476
#   - loop: 1477
#   - loop: 1483
#   - loop: 1482
#   - loop: 1490
#   - loop: 1480
#   - loop: 1483
#   - loop: 1482
#   - loop: 1486
#   - loop: 650
#  - per count:  24374
#  counter:  4
#   - loop: 1482
#   - loop: 1479
#   - loop: 1488
#   - loop: 1486
#   - loop: 1483
#   - loop: 1482
#   - loop: 1478
#   - loop: 1493
#   - loop: 1484
#   - loop: 1484
#   - loop: 1486
#   - loop: 1486
#   - loop: 1482
#   - loop: 1491
#   - loop: 1484
#   - loop: 1487
#   - loop: 373
#  - per count:  24128
#  counter:  5
#   - loop: 1481
#   - loop: 1479
#   - loop: 1487
#   - loop: 1487
#   - loop: 1484
#   - loop: 1489
#   - loop: 1490
#   - loop: 1485
#   - loop: 1485
#   - loop: 1491
#   - loop: 1489
#   - loop: 1488
#   - loop: 1489
#   - loop: 1478
#   - loop: 1489
#   - loop: 1484
#   - loop: 128
#  - per count:  23903
#  counter:  6
#   - loop: 1487
#   - loop: 1480
#   - loop: 1484
#   - loop: 1483
#   - loop: 1485
#   - loop: 1488
#   - loop: 1483
#   - loop: 1491
#   - loop: 1483
#   - loop: 1486
#   - loop: 1484
#   - loop: 1489
#   - loop: 1489
#   - loop: 1487
#   - loop: 1487
#   - loop: 1395
#  - per count:  23681
# ../spider_1_2  :  19998
#  counter:  1
#   - loop: 1224
#   - loop: 1049
#   - loop: 903
#   - loop: 917
#   - loop: 899
#   - loop: 1118
#   - loop: 1189
#   - loop: 1041
#   - loop: 1021
#   - loop: 1003
#   - loop: 1231
#   - loop: 1272
#   - loop: 1499
#   - loop: 498
#  - per count:  14864
#  counter:  2
#   - loop: 1161
#   - loop: 1149
#   - loop: 1149
#   - loop: 1154
#   - loop: 1165
#   - loop: 1178
#   - loop: 1146
#   - loop: 1166
#   - loop: 1166
#   - loop: 1072
#  - per count:  11506
#  counter:  3
#   - loop: 1184
#   - loop: 1214
#   - loop: 1195
#   - loop: 1206
#   - loop: 1185
#   - loop: 1207
#   - loop: 1164
#   - loop: 874
#  - per count:  9229
#  counter:  4
#   - loop: 1209
#   - loop: 1221
#   - loop: 1221
#   - loop: 1217
#   - loop: 1199
#   - loop: 1217
#   - loop: 218
#  - per count:  7502
#  counter:  5
#   - loop: 1279
#   - loop: 1244
#   - loop: 1256
#   - loop: 1271
#   - loop: 1256
#   - loop: 2
#  - per count:  6308
#  counter:  6
#   - loop: 1275
#   - loop: 1270
#   - loop: 1284
#   - loop: 1277
#   - loop: 292
#  - per count:  5398
# ../spider_1_4  :  4367
#  counter:  1
#   - loop: 545
#   - loop: 535
#   - loop: 599
#  - per count:  1679
#  counter:  2
#   - loop: 599
#   - loop: 164
#  - per count:  763
#  counter:  3
#   - loop: 601
#  - per count:  601
#  counter:  4
#   - loop: 601
#  - per count:  601
# ../spider_1_6  :  3188
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#  counter:  1
#   - loop: 1182
#   - loop: 1140
#   - loop: 169
#  - per count:  2491
#  counter:  2
#   - loop: 1253
#   - loop: 883
#  - per count:  2136
#  counter:  3
#   - loop: 1366
#   - loop: 614
#  - per count:  1980
#  counter:  4
#   - loop: 1438
#   - loop: 471
#  - per count:  1909
#  counter:  5
#   - loop: 1470
#   - loop: 407
#  - per count:  1877
#  counter:  6
#   - loop: 1490
#   - loop: 376
#  - per count:  1866

# %%
len(final_csv_file)
# Out:
# 0

# %% [markdown]
# ## Preprocessing

# %%
! pip install hazm
# Out:
# Collecting hazm
#   Downloading https://files.pythonhosted.org/packages/22/13/5a7074bc11d20dbbb46239349ac3f85f7edc148b4cf68e9b8c2f8263830c/hazm-0.7.0-py3-none-any.whl (316kB)
#      |████████████████████████████████| 317kB 5.4MB/s
# Collecting libwapiti>=0.2.1; platform_system != "Windows"
#   Downloading https://files.pythonhosted.org/packages/bc/0f/1c9b49bb49821b5856a64ea6fac8d96a619b9f291d1f06999ea98a32c89c/libwapiti-0.2.1.tar.gz (233kB)
#      |████████████████████████████████| 235kB 7.2MB/s
# Collecting nltk==3.3
#   Downloading https://files.pythonhosted.org/packages/50/09/3b1755d528ad9156ee7243d52aa5cd2b809ef053a0f31b53d92853dd653a/nltk-3.3.0.zip (1.4MB)
#      |████████████████████████████████| 1.4MB 8.4MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from libwapiti>=0.2.1; platform_system != "Windows"->hazm) (1.15.0)
# Building wheels for collected packages: libwapiti, nltk
#   Building wheel for libwapiti (setup.py) ... done
#   Created wheel for libwapiti: filename=libwapiti-0.2.1-cp36-cp36m-linux_x86_64.whl size=154353 sha256=1c457624baf03c1e17549a671a626b9674e22f3bf18ae8a0c77f564e77c9843a
#   Stored in directory: /root/.cache/pip/wheels/66/15/54/4510dce8bb958b1cdd2c47425cbd1e1eecc0480ac9bb1fb9ab
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.3-cp36-none-any.whl size=1394471 sha256=4896a28f928470c412dee64b0fd9141939e40789a1ea110e18b99f62b7d99077
#   Stored in directory: /root/.cache/pip/wheels/d1/ab/40/3bceea46922767e42986aef7606a600538ca80de6062dc266c
# Successfully built libwapiti nltk
# Installing collected packages: libwapiti, nltk, hazm
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# Successfully installed hazm-0.7.0 libwapiti-0.2.1 nltk-3.3

# %%
from hazm import *
normalizer=Normalizer()
stemmer=Stemmer()
lemmatizer=Lemmatizer()

def Normalizer(text):

    # normalizer = Normalizer()
    normalized = normalizer.normalize(text)

    return normalized


def SentenceSplitter_Tokenizer(text):

    Tokens=list(word_tokenize(text))

    return Tokens

def Stemmer(token):

    stemming=[]
    for word in token:
        stemming.append(lemmatizer.lemmatize(word))

    return stemming

def RemoveStopwords_Punc(token):

    with open('../Data/stopwords') as f:
        sw = [line.rstrip().replace(" ","").replace("\u200c","") for line in f]
    # print(sw)

    punctuation = '!"#$%&\'()*+–,-./:;<=>?@[\\]^_`{|}~،؟«؛'
    result=[]
    for word in token:
        for s in punctuation:
            if s in word:
                word=word.replace(s,"")
            # print(word)
        if word.replace(" ","").replace("\u200c","") in sw:
            continue

        result.append(word)

    # print(result)
    return result

def EmojiRemoving(text):

    emoj = re.compile("["
                      u"\U0001F600-\U0001F64F"  # emoticons
                      u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                      u"\U0001F680-\U0001F6FF"  # transport & map symbols
                      u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                      u"\U00002500-\U00002BEF"  # chinese char
                      u"\U00002702-\U000027B0"
                      u"\U00002702-\U000027B0"
                      u"\U000024C2-\U0001F251"
                      u"\U0001f926-\U0001f937"
                      u"\U00010000-\U0010ffff"
                      u"\u2640-\u2642"
                      u"\u2600-\u2B55"
                      u"\u200d"
                      u"\u23cf"
                      u"\u23e9"
                      u"\u231a"
                      u"\ufe0f"  # dingbats
                      u"\u3030"
                      "]+", re.UNICODE)
    text= re.sub(emoj, '', text)

    return text

# %%
data = pd.read_csv('../Data/unpreprocessed_dataset.csv')

# %%
# counter
count_data = data.copy()
count_data = count_data.dropna().reset_index(drop=True)
count = {}
tags_list = pd.read_excel('../Tags.xlsx',header = None)
tags_list.columns = ['tag']
for _,tag in tags_list.iterrows():
  if tag['tag']!='ویرگول' and tag['tag']!=None and tag['tag']!='':
    count[re.sub(' ','',tag['tag'].lower())] = 0

for indx,d in count_data.iterrows():
  tags = re.sub('\'|\[|\]','',d['tag']).split(',')
  
  for tag in tags:
    if tag.strip().lower() in tags_list.values:
      count[tag.strip().lower().replace(' ','')]+=1 
count
# Out:
# {'api': 581,
#  'c': 3735,
#  'css': 1284,
#  'designpattern': 88,
#  'devops': 68,
#  'golang': 80,
#  'html': 1410,
#  'ios': 261,
#  'nodejs': 222,
#  'oop': 585,
#  'php': 1008,
#  'reactnative': 34,
#  'redux': 57,
#  'ubuntu': 84,
#  'vscode': 81,
#  'آموزشبرنامهنویسی': 1264,
#  'آموزشپایتون': 519,
#  'استارتاپ': 2839,
#  'استخدام': 631,
#  'الگوریتم': 311,
#  'امنیت': 772,
#  'اندروید': 722,
#  'اندرویداستودیو': 203,
#  'اپلیکیشن': 738,
#  'اینترنت': 370,
#  'اینستاگرام': 1020,
#  'برنامهنویسی': 949,
#  'برنامهنویسیاندروید': 808,
#  'برنامهنویسیوب': 636,
#  'تجربهکاربری': 784,
#  'تحلیلداده': 283,
#  'تلگرام': 482,
#  'توسعهدهنده': 551,
#  'توسعهوب': 1099,
#  'تکنولوژی': 509,
#  'جاوا': 920,
#  'جاوااسکریپت': 1136,
#  'جنگو': 69,
#  'دادهکاوی': 222,
#  'داکر': 160,
#  'دیجیتالمارکتینگ': 1176,
#  'رابطکاربری': 576,
#  'ریاکت': 405,
#  'زبانبرنامهنویسی': 1040,
#  'سئو': 1167,
#  'سیشارپ': 119,
#  'شیگرایی': 175,
#  'طراحیسایت': 1340,
#  'طراحیوب': 1482,
#  'علمداده': 289,
#  'فرانتاند': 155,
#  'فلاتر': 121,
#  'فناوری': 286,
#  'لاراول': 466,
#  'لینوکس': 763,
#  'مصاحبه': 211,
#  'مهارت': 282,
#  'مهندسینرمافزار': 201,
#  'موفقیت': 3061,
#  'نرمافزار': 939,
#  'هوشمصنوعی': 970,
#  'هک': 310,
#  'وب': 2394,
#  'وردپرس': 825,
#  'ویندوز': 417,
#  'پایتون': 1126,
#  'کاتلین': 144,
#  'کامپیوتر': 602,
#  'کتاب': 3324,
#  'کد': 2421,
#  'کدنویسی': 560,
#  'کسبوکار': 3518,
#  'گوگل': 605,
#  'گیت': 200,
#  'گیتهاب': 150,
#  'یادگیری': 960,
#  'یادگیریعمیق': 311,
#  'یادگیریماشین': 615}

# %%
downly_tags = [i for i in list(count.keys()) if count[i]<100]
less_than_80 = [i for i in list(count.keys()) if count[i]<80]
less_than_80
# Out:
# ['redux', 'reactnative', 'جنگو', 'devops']

# %%
# [count[tag.replace(' ','')] for tag in tags_list if (tag.replace(' ','') in list(count.keys()))]
# [i for i in tags.split(',') if i!=' ' and i!='']
tags = data.loc[17325,'tag']
# tags = re.sub('\[|\]|\'',' ',tags)
# [i.strip() for i in tags.split(',') if (i!=' ' and i!='' and (i.strip() in list(count.keys()) ))]

# %%
data = pd.read_csv('../Data/unpreprocessed_dataset.csv')
slice_size = 150
for i in range(len(data)):

    text=data.loc[i,"body"]

    tags = data.loc[i,'tag']
    tags = re.sub('\[|\]|\'|=',' ',tags)
    tags_list = [t.strip() for t  in tags.split(',') if (t!=' ' and t!='' and (re.sub('[ ]*','',t) in list(count.keys())))]
    if len(tags_list)==0:
      data.loc[i,'body'] = None    
      if i%3000==0:
        print("Record: up to "+str(i)+" from " ,str(len(data)),"is processed then breaked.")
      continue
    
    # remove half-space

    text = text.replace("\u200c", " ")
    text = text.replace("های ", " ها ی ")
    text = text.replace("ها ", " ها ")
    text=EmojiRemoving(text)
    normalized = Normalizer(text)
    split = SentenceSplitter_Tokenizer(normalized)
    tokens = RemoveStopwords_Punc(split)
    tokens = [t for t in tokens if len(t)>2]
    tokens_slice = []

    # balancing
    
    min_count = min([count[tag.replace(' ','')] for tag in tags_list if (tag.replace(' ','') in list(count.keys()))])

    if min_count<80 :
      loop_0 = len(tokens)//300
      loop_1 = int(min_count/(loop_0+1))

      for j in range(loop_0):
          d_temp = data.iloc[i,:].copy()

          for tag in tags_list:
            count[tag.replace(' ','')] += 1

          d_temp['body'] = tokens[j*300:min(len(tokens),(j+1)*300)]
          for _ in range(loop_1):
            data = data.append(d_temp)

    if len(tokens)> 2*slice_size:
      tokens_slice += tokens[:slice_size]
      tokens_slice += tokens[-slice_size:]
    else:
      tokens_slice += tokens

    if tokens_slice!= None:
      data.loc[i, "body"] = re.sub('[ ]*|\\u200c','',str(tokens_slice)).replace('\\u200c','')
    else:
      data.loc[i, "body"] = None

    # clarifying tags

    text = re.sub('\'|,|\[|\]','',str(tokens_slice))

    detected_tags = []
    for tag in tags_list:
      if tag.strip().replace(' ','') in downly_tags:
        detected_tags += [tag]
      else:
        temp = tag.strip().replace(' ','|')
        t = temp.lower() + '|' + temp.upper()

        if 'nodejs' in t:
          t= t + '|node js|نود جی اس'
        if 'اینستاگرام' in t:
          t= t + '|instagram'
        if 'هک' in t:
          t= t + '|hack'
        if 'pattern' in t:
          t= t + '|دیزاین پترن|دیزاین |پترن'
        try:
          if t!='|' and len(re.findall(t , text))!=0:
            detected_tags+= [tag]
        except:
          pass

    if len(detected_tags)==0:
      data.loc[i,'body'] = None

      
    if i%3000==0:
      print("Record: up to "+str(i)+" from " ,str(len(data)),"is processed.")

# %%
data.loc[169,'tag']
# Out:
# "'' زبان برنامه نویسی''"

# %%
data = data.dropna().reset_index(drop=True)

# %%
data.loc[:,['body','tag']].to_csv("../Data/preprocessed_non_related_tags_removed.csv", index=False)

# %%
# counter
count_data = data.copy()
count_data = count_data.dropna().reset_index(drop=True)
count = {}
tags_list = pd.read_excel('../Tags.xlsx',header = None)
tags_list.columns = ['tag']
for _,tag in tags_list.iterrows():
  if tag['tag']!='ویرگول' and tag['tag']!=None and tag['tag']!='':
    count[re.sub(' ','',tag['tag'].lower())] = 0

for indx,d in count_data.iterrows():
  tags = re.sub('\'|\[|\]','',d['tag']).split(',')
  
  for tag in tags:
    if tag.strip().lower() in tags_list.values:
      count[tag.strip().lower().replace(' ','')]+=1 
# count

# %%
data.loc[:100,['body','tag']].head()
# Out:
#                                                 body                        tag
# 0  ['جزو','دولوپرهایی','سال','کدنویسی','کسب','تجر...                 '' مهارت''
# 1  ['دولوپرها','ابزارها','مختلفی','فرایند','کدنوی...                '' کاتلین''
# 2  ['میشناسید','جزو','توسعه','دهندگان','فعالان','...  '' برنامه نویسی اندروید''
# 3  ['Microsoft','Research','Open','Data','ریپازیت...             '' داده کاوی''
# 4  ['کامپیوترها','بزرگی','زندگی','تشکیل','دادهاند...              '' کامپیوتر''

# %%
# len(set(list(count.keys())))
count.keys()
# Out:
# dict_keys(['برنامهنویسی', 'پایتون', 'اندروید', 'جاوااسکریپت', 'هوشمصنوعی', 'ریاکت', 'لینوکس', 'php', 'یادگیریماشین', 'لاراول', 'نرمافزار', 'آموزشبرنامهنویسی', 'وب', 'کامپیوتر', 'مهندسینرمافزار', 'استارتاپ', 'تکنولوژی', 'برنامهنویسیاندروید', 'یادگیری', 'امنیت', 'گیت', 'جاوا', 'فلاتر', 'کاتلین', 'طراحیوب', 'کسبوکار', 'توسعهدهنده', 'کدنویسی', 'داکر', 'nodejs', 'علمداده', 'فرانتاند', 'زبانبرنامهنویسی', 'golang', 'سئو', 'استخدام', 'کد', 'آموزشپایتون', 'الگوریتم', 'اینترنت', 'css', 'گوگل', 'طراحیسایت', 'api', 'مصاحبه', 'redux', 'دادهکاوی', 'موفقیت', 'یادگیریعمیق', 'هک', 'وردپرس', 'تجربهکاربری', 'رابطکاربری', 'دیجیتالمارکتینگ', 'تحلیلداده', 'ویندوز', 'oop', 'reactnative', 'تلگرام', 'گیتهاب', 'ubuntu', 'designpattern', 'برنامهنویسیوب', 'html', 'سیشارپ', 'شیگرایی', 'کتاب', 'جنگو', 'اندرویداستودیو', 'اینستاگرام', 'فناوری', 'مهارت', 'devops', 'ios', 'توسعهوب', 'اپلیکیشن', 'c', 'vscode'])

# %% [markdown]
# ## Limit Number of Samples

# %%
data = pd.read_csv('../Data/preprocessed_non_related_tags_removed.csv')

# %%
tags = pd.read_excel('../Tags.xlsx',header = None)
tags.columns = ['tag']

# %%
# counter
count_data = data.copy()
count_data = count_data.dropna().reset_index(drop=True)
count = {}
tags_list = pd.read_excel('../Tags.xlsx',header = None)
tags_list.columns = ['tag']
for _,tag in tags_list.iterrows():
  if tag['tag']!='ویرگول' and tag['tag']!=None and tag['tag']!='':
    count[re.sub(' ','',tag['tag'].lower())] = 0

for indx,d in count_data.iterrows():
  tags = re.sub('\'|\[|\]','',d['tag']).split(',')
  
  for tag in tags:
    if tag.strip().lower() in tags_list.values:
      count[tag.strip().lower().replace(' ','')]+=1 
      
len(set(list(count.keys())))
# Out:
# 78

# %%
count = {}
limit_number = 750
data_temp = data.copy().sample(frac=1)
limited_data = pd.DataFrame(columns=['body','tag'])

tags_list = pd.read_excel('../Tags.xlsx',header = None)
tags_list.columns = ['tag']

for _,tag in tags_list.iterrows():
  if tag['tag']!='ویرگول' and tag['tag']!=None and tag['tag']!='':
    count[re.sub(' ','',tag['tag'].lower())] = 0

for indx,d in data_temp.iterrows():

  new_tags = []

  tags = re.sub('\'|\[|\]','',d['tag']).split(',')
  
  for tag in tags:
    if tag.strip().lower() in tags_list.values:
      count[tag.strip().lower().replace(' ','')]+=1 
      if count[tag.strip().lower().replace(' ','')] <=limit_number:
        new_tags.append(tag)


  if len(new_tags)>0:
    d['tag']=str(list(set(new_tags)))
    limited_data = limited_data.append(d)
  else:
    d['body'] = None
limited_data = limited_data.reset_index(drop=True)
print(limited_data.shape)
print(len(set(list(count.keys()))))
limited_data.head()
# Out:
# (21559, 2)
# 78
#                                                 body                                                tag
# 0  ['قسمت','ادامه','ترفندها','پیشرفته','jQuery','...        [' نرم افزار', ' کد', 'html', ' css', ' c']
# 1  ['زبان','برنامه','نویسی','خواندن','درک','دشوار...  [' آموزش برنامه نویسی', ' برنامه نویسی اندروید...
# 2  ['کتاب','جامعه','خودمانی','میخواندم','صفحه','ا...                                           ['کتاب']
# 3  ['افتادهباشید','اینستاگرام','کامپیوتر','باشیدد...                                     ['اینستاگرام']
# 4  ['روزها','بازار','استارتاپها','داغ','کشورها','...                                       ['استارتاپ']

# %%
# counter
count_data = limited_data.copy()
count_data = count_data.dropna().reset_index(drop=True)
count = {}
tags_list = pd.read_excel('../Tags.xlsx',header = None)
tags_list.columns = ['tag']
for _,tag in tags_list.iterrows():
  if tag['tag']!='ویرگول' and tag['tag']!=None and tag['tag']!='':
    count[re.sub(' ','',tag['tag'].lower())] = 0

for indx,d in count_data.iterrows():
  tags = re.sub('\'|\[|\]','',d['tag']).split(',')
  
  for tag in tags:
    if tag.strip().lower() in tags_list.values:
      count[tag.strip().lower().replace(' ','')]+=1 
print([i for i in list(count.keys()) if count[i]<50])
count
# Out:
# []
# {'api': 582,
#  'c': 750,
#  'css': 749,
#  'designpattern': 88,
#  'devops': 400,
#  'golang': 74,
#  'html': 750,
#  'ios': 198,
#  'nodejs': 137,
#  'oop': 532,
#  'php': 750,
#  'reactnative': 377,
#  'redux': 677,
#  'ubuntu': 84,
#  'vscode': 81,
#  'آموزشبرنامهنویسی': 749,
#  'آموزشپایتون': 663,
#  'استارتاپ': 750,
#  'استخدام': 533,
#  'الگوریتم': 335,
#  'امنیت': 642,
#  'اندروید': 639,
#  'اندرویداستودیو': 189,
#  'اپلیکیشن': 747,
#  'اینترنت': 362,
#  'اینستاگرام': 750,
#  'برنامهنویسی': 750,
#  'برنامهنویسیاندروید': 750,
#  'برنامهنویسیوب': 631,
#  'تجربهکاربری': 698,
#  'تحلیلداده': 311,
#  'تلگرام': 430,
#  'توسعهدهنده': 620,
#  'توسعهوب': 750,
#  'تکنولوژی': 393,
#  'جاوا': 749,
#  'جاوااسکریپت': 750,
#  'جنگو': 344,
#  'دادهکاوی': 257,
#  'داکر': 150,
#  'دیجیتالمارکتینگ': 750,
#  'رابطکاربری': 568,
#  'ریاکت': 404,
#  'زبانبرنامهنویسی': 750,
#  'سئو': 750,
#  'سیشارپ': 114,
#  'شیگرایی': 171,
#  'طراحیسایت': 750,
#  'طراحیوب': 749,
#  'علمداده': 354,
#  'فرانتاند': 143,
#  'فلاتر': 116,
#  'فناوری': 212,
#  'لاراول': 477,
#  'لینوکس': 660,
#  'مصاحبه': 186,
#  'مهارت': 304,
#  'مهندسینرمافزار': 260,
#  'موفقیت': 750,
#  'نرمافزار': 750,
#  'هوشمصنوعی': 750,
#  'هک': 244,
#  'وب': 750,
#  'وردپرس': 750,
#  'ویندوز': 438,
#  'پایتون': 750,
#  'کاتلین': 172,
#  'کامپیوتر': 504,
#  'کتاب': 750,
#  'کد': 750,
#  'کدنویسی': 664,
#  'کسبوکار': 750,
#  'گوگل': 609,
#  'گیت': 187,
#  'گیتهاب': 131,
#  'یادگیری': 750,
#  'یادگیریعمیق': 332,
#  'یادگیریماشین': 599}

# %%
limited_data.to_csv('../Data/limited_to_'+str(limit_number)+'.csv')
'../limited_to_'+str(limit_number)+'.csv'
# Out:
# '../limited_to_750.csv'

# %%
labels = []
for item in limited_data['tag']:
  labels += [i for i in re.sub('\"|\[|\]|\'| |=','',item.lower()).split(",") if i!='' and i!=' ']
labels = list(set(labels))

y = pd.read_csv('../Data/limited_to_750.csv')
labels = []
tag=[]
for item in y['tag']:
  labels += [i for i in re.sub('\"|\[|\]|\'| |=','',item.lower()).split(",") if i!='' and i!=' ']
  tag.append([i for i in re.sub('\"|\[|\]|\'| |=','',item.lower()).split(",") if i!='' and i!=' '])
labels = list(set(labels))

len(labels)
# Out:
# 78

# %% [markdown]
# ## FreqDist

# %%
from nltk import FreqDist

# %%
all_tokens = []
for body in data['body']:
  all_tokens+= re.sub('\'|\"|\[|\]| ',',',body).split(',')

# %%
fd_all = FreqDist(all_tokens)
fd_all[0]
# Out:
# 0

# %%
keys = pd.DataFrame([(item,fd_all[item]) for item in fd_all])
keys.columns = ['word','freq']
keys = keys.sort_values(by=['freq'],ascending=False)
keys = keys.reset_index(drop=True)
# keys.to_csv('../Data/FreqDist_sorted.csv', index=False)
keys.to_csv('../Data/FreqDist_sorted_'+str(limit_number)+'.csv', index=False)

# %%
keys.head()
# Out:
#      word      freq
# 0          13074570
# 1     کار     66702
# 2  برنامه     42729
# 3    قرار     39322
# 4    سایت     30886
